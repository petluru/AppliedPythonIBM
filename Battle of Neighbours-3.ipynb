# %%
import pandas as pd
import numpy as np
from IPython.display import Markdown,display
# !conda install -c conda-forge folium=0.5.0 --yes 
import folium
html_doc = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
display(Markdown("__Reading HTML data with pandas API and extracting table__"))
# Out:
# __Reading HTML data with pandas API and extracting table__

# %%
postal_df = pd.DataFrame(pd.read_html(html_doc)[0])
display(Markdown("__Removing rows with cells with a borough that is Not assigned.__"))
# Out:
# __Removing rows with cells with a borough that is Not assigned.__

# %%
postal_df = postal_df.drop(index=postal_df[postal_df.Borough == 'Not assigned'].index).sort_values(['Postcode']).reset_index(drop=True)
display(Markdown("__For the row with Neighbourhood as Not assigned making the value of the Neighborhood same as that of its Borough column.__"))
# Out:
# __For the row with Neighbourhood as Not assigned making the value of the Neighborhood same as that of its Borough column.__

# %%
postal_df.loc[postal_df[postal_df.Neighbourhood == 'Not assigned'].index,'Neighbourhood'] = postal_df[postal_df.Neighbourhood == 'Not assigned'].Borough
display(Markdown("__For postal codes areas having  more than one neighborhood combining into one row with the neighborhoods separated with a comma.__"))
# Out:
# __For postal codes areas having  more than one neighborhood combining into one row with the neighborhoods separated with a comma.__

# %%
neighbourlist = []
for i , d in postal_df.groupby(['Postcode','Borough']):
    neighbourlist.append(d.Neighbourhood.values)
neighbourlist = [list(r) for r in neighbourlist]
display(Markdown("__Dropping the duplicate values of data.__"))
# Out:
# __Dropping the duplicate values of data.__

# %%
postal_df = postal_df.drop_duplicates(subset=['Postcode'],keep='first').reset_index(drop=True)
display(Markdown("__Convering list of Neighbourhoods onto concatenated string.__"))
# Out:
# __Convering list of Neighbourhoods onto concatenated string.__

# %%
for i in range(len(postal_df)):
    postal_df.loc[i,'Neighbourhood'] = str(neighbourlist[i])[1:-1]

# %%
display(Markdown("__Displaying the Data Frame.__"))
postal_df
# Out:
# __Displaying the Data Frame.__
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# 29       M3J        North York
# ..       ...               ...
# 73       M6C              York
# 74       M6E              York
# 75       M6G  Downtown Toronto
# 76       M6H      West Toronto
# 77       M6J      West Toronto
# 78       M6K      West Toronto
# 79       M6L        North York
# 80       M6M              York
# 81       M6N              York
# 82       M6P      West Toronto
# 83       M6R      West Toronto
# 84       M6S      West Toronto
# 85       M7A      Queen's Park
# 86       M7R       Mississauga
# 87       M7Y      East Toronto
# 88       M8V         Etobicoke
# 89       M8W         Etobicoke
# 90       M8X         Etobicoke
# 91       M8Y         Etobicoke
# 92       M8Z         Etobicoke
# 93       M9A      Queen's Park
# 94       M9B         Etobicoke
# 95       M9C         Etobicoke
# 96       M9L        North York
# 97       M9M        North York
# 98       M9N              York
# 99       M9P         Etobicoke
# 100      M9R         Etobicoke
# 101      M9V         Etobicoke
# 102      M9W         Etobicoke
#
#                                          Neighbourhood
# 0                                   'Rouge', 'Malvern'
# 1         'Port Union', 'Rouge Hill', 'Highland Creek'
# 2              'Guildwood', 'Morningside', 'West Hill'
# 3                                             'Woburn'
# 4                                          'Cedarbrae'
# 5                                'Scarborough Village'
# 6    'East Birchmount Park', 'Ionview', 'Kennedy Park'
# 7                'Golden Mile', 'Oakridge', 'Clairlea'
# 8    'Cliffcrest', 'Scarborough Village West', 'Cli...
# 9                      'Cliffside West', 'Birch Cliff'
# 10   'Wexford Heights', 'Dorset Park', 'Scarborough...
# 11                               'Maryvale', 'Wexford'
# 12                                         'Agincourt'
# 13       'Sullivan', 'Clarks Corners', "Tam O'Shanter"
# 14   'Steeles East', 'Milliken', "L'Amoreaux East",...
# 15                                   "L'Amoreaux West"
# 16                                       'Upper Rouge'
# 17                                 'Hillcrest Village'
# 18                  'Henry Farm', 'Fairview', 'Oriole'
# 19                                   'Bayview Village'
# 20                        'Silver Hills', 'York Mills'
# 21                         'Willowdale', 'Newtonbrook'
# 22                                  'Willowdale South'
# 23                                   'York Mills West'
# 24                                   'Willowdale West'
# 25                                         'Parkwoods'
# 26                                   'Don Mills North'
# 27                'Don Mills South', 'Flemingdon Park'
# 28   'Bathurst Manor', 'Wilson Heights', 'Downsview...
# 29                 'Northwood Park', 'York University'
# ..                                                 ...
# 73                                'Humewood-Cedarvale'
# 74                               'Caledonia-Fairbanks'
# 75                                          'Christie'
# 76                    'Dufferin', 'Dovercourt Village'
# 77                        'Little Portugal', 'Trinity'
# 78   'Exhibition Place', 'Brockton', 'Parkdale Vill...
# 79            'Downsview', 'North Park', 'Upwood Park'
# 80   'Silverthorn', 'Mount Dennis', 'Keelesdale', '...
# 81                   'The Junction North', 'Runnymede'
# 82                   'High Park', 'The Junction South'
# 83                          'Roncesvalles', 'Parkdale'
# 84                              'Runnymede', 'Swansea'
# 85                                      "Queen's Park"
# 86             'Canada Post Gateway Processing Centre'
# 87   'Business Reply Mail Processing Centre 969 Eas...
# 88   'Mimico South', 'New Toronto', 'Humber Bay Sho...
# 89                          'Long Branch', 'Alderwood'
# 90   'Old Mill North', 'Montgomery Road', 'The King...
# 91   'Old Mill South', "King's Mill Park", 'Humber ...
# 92   'Kingsway Park South West', 'Mimico NW', 'The ...
# 93                                      "Queen's Park"
# 94   'Cloverdale', 'West Deane Park', 'Princess Gar...
# 95   'Old Burnhamthorpe', 'Markland Wood', 'Eringat...
# 96                                     'Humber Summit'
# 97                                'Humberlea', 'Emery'
# 98                                            'Weston'
# 99                                         'Westmount'
# 100  'Richview Gardens', 'Kingsview Village', 'St. ...
# 101  'Albion Gardens', 'Beaumond Heights', 'Humberg...
# 102                                        'Northwest'
#
# [103 rows x 3 columns]

# %%
display(Markdown("__Printing the shape of data frame.__"))
postal_df.shape
# Out:
# __Printing the shape of data frame.__
# (103, 3)

# %%
display(Markdown("__Getting the Geospatial data.__"))
geo_data = pd.read_csv("http://cocl.us/Geospatial_data")
display(Markdown("__Renaming the columns to merge .__"))
geo_data = geo_data.rename(columns={"Postal Code":"Postcode"})
# Out:
# __Getting the Geospatial data.__
# __Renaming the columns to merge .__

# %%
postal_df = postal_df.merge(geo_data,on=['Postcode'])

# %%
display(Markdown("__Dataframe with Coordinates of respective postal codes.__"))
postal_df
# Out:
# __Dataframe with Coordinates of respective postal codes.__
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# 29       M3J        North York
# ..       ...               ...
# 73       M6C              York
# 74       M6E              York
# 75       M6G  Downtown Toronto
# 76       M6H      West Toronto
# 77       M6J      West Toronto
# 78       M6K      West Toronto
# 79       M6L        North York
# 80       M6M              York
# 81       M6N              York
# 82       M6P      West Toronto
# 83       M6R      West Toronto
# 84       M6S      West Toronto
# 85       M7A      Queen's Park
# 86       M7R       Mississauga
# 87       M7Y      East Toronto
# 88       M8V         Etobicoke
# 89       M8W         Etobicoke
# 90       M8X         Etobicoke
# 91       M8Y         Etobicoke
# 92       M8Z         Etobicoke
# 93       M9A      Queen's Park
# 94       M9B         Etobicoke
# 95       M9C         Etobicoke
# 96       M9L        North York
# 97       M9M        North York
# 98       M9N              York
# 99       M9P         Etobicoke
# 100      M9R         Etobicoke
# 101      M9V         Etobicoke
# 102      M9W         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                   'Rouge', 'Malvern'  43.806686 -79.194353
# 1         'Port Union', 'Rouge Hill', 'Highland Creek'  43.784535 -79.160497
# 2              'Guildwood', 'Morningside', 'West Hill'  43.763573 -79.188711
# 3                                             'Woburn'  43.770992 -79.216917
# 4                                          'Cedarbrae'  43.773136 -79.239476
# 5                                'Scarborough Village'  43.744734 -79.239476
# 6    'East Birchmount Park', 'Ionview', 'Kennedy Park'  43.727929 -79.262029
# 7                'Golden Mile', 'Oakridge', 'Clairlea'  43.711112 -79.284577
# 8    'Cliffcrest', 'Scarborough Village West', 'Cli...  43.716316 -79.239476
# 9                      'Cliffside West', 'Birch Cliff'  43.692657 -79.264848
# 10   'Wexford Heights', 'Dorset Park', 'Scarborough...  43.757410 -79.273304
# 11                               'Maryvale', 'Wexford'  43.750072 -79.295849
# 12                                         'Agincourt'  43.794200 -79.262029
# 13       'Sullivan', 'Clarks Corners', "Tam O'Shanter"  43.781638 -79.304302
# 14   'Steeles East', 'Milliken', "L'Amoreaux East",...  43.815252 -79.284577
# 15                                   "L'Amoreaux West"  43.799525 -79.318389
# 16                                       'Upper Rouge'  43.836125 -79.205636
# 17                                 'Hillcrest Village'  43.803762 -79.363452
# 18                  'Henry Farm', 'Fairview', 'Oriole'  43.778517 -79.346556
# 19                                   'Bayview Village'  43.786947 -79.385975
# 20                        'Silver Hills', 'York Mills'  43.757490 -79.374714
# 21                         'Willowdale', 'Newtonbrook'  43.789053 -79.408493
# 22                                  'Willowdale South'  43.770120 -79.408493
# 23                                   'York Mills West'  43.752758 -79.400049
# 24                                   'Willowdale West'  43.782736 -79.442259
# 25                                         'Parkwoods'  43.753259 -79.329656
# 26                                   'Don Mills North'  43.745906 -79.352188
# 27                'Don Mills South', 'Flemingdon Park'  43.725900 -79.340923
# 28   'Bathurst Manor', 'Wilson Heights', 'Downsview...  43.754328 -79.442259
# 29                 'Northwood Park', 'York University'  43.767980 -79.487262
# ..                                                 ...        ...        ...
# 73                                'Humewood-Cedarvale'  43.693781 -79.428191
# 74                               'Caledonia-Fairbanks'  43.689026 -79.453512
# 75                                          'Christie'  43.669542 -79.422564
# 76                    'Dufferin', 'Dovercourt Village'  43.669005 -79.442259
# 77                        'Little Portugal', 'Trinity'  43.647927 -79.419750
# 78   'Exhibition Place', 'Brockton', 'Parkdale Vill...  43.636847 -79.428191
# 79            'Downsview', 'North Park', 'Upwood Park'  43.713756 -79.490074
# 80   'Silverthorn', 'Mount Dennis', 'Keelesdale', '...  43.691116 -79.476013
# 81                   'The Junction North', 'Runnymede'  43.673185 -79.487262
# 82                   'High Park', 'The Junction South'  43.661608 -79.464763
# 83                          'Roncesvalles', 'Parkdale'  43.648960 -79.456325
# 84                              'Runnymede', 'Swansea'  43.651571 -79.484450
# 85                                      "Queen's Park"  43.662301 -79.389494
# 86             'Canada Post Gateway Processing Centre'  43.636966 -79.615819
# 87   'Business Reply Mail Processing Centre 969 Eas...  43.662744 -79.321558
# 88   'Mimico South', 'New Toronto', 'Humber Bay Sho...  43.605647 -79.501321
# 89                          'Long Branch', 'Alderwood'  43.602414 -79.543484
# 90   'Old Mill North', 'Montgomery Road', 'The King...  43.653654 -79.506944
# 91   'Old Mill South', "King's Mill Park", 'Humber ...  43.636258 -79.498509
# 92   'Kingsway Park South West', 'Mimico NW', 'The ...  43.628841 -79.520999
# 93                                      "Queen's Park"  43.667856 -79.532242
# 94   'Cloverdale', 'West Deane Park', 'Princess Gar...  43.650943 -79.554724
# 95   'Old Burnhamthorpe', 'Markland Wood', 'Eringat...  43.643515 -79.577201
# 96                                     'Humber Summit'  43.756303 -79.565963
# 97                                'Humberlea', 'Emery'  43.724766 -79.532242
# 98                                            'Weston'  43.706876 -79.518188
# 99                                         'Westmount'  43.696319 -79.532242
# 100  'Richview Gardens', 'Kingsview Village', 'St. ...  43.688905 -79.554724
# 101  'Albion Gardens', 'Beaumond Heights', 'Humberg...  43.739416 -79.588437
# 102                                        'Northwest'  43.706748 -79.594054
#
# [103 rows x 5 columns]

# %%
display(Markdown("__Getting the coordinates of torento from geopy geocoders library.__"))
from geopy.geocoders import Nominatim
# import folium
address = 'Toronto'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Torento  are {}, {}.'.format(latitude, longitude))
# Out:
# __Getting the coordinates of torento from geopy geocoders library.__
# The geograpical coordinate of Torento  are 43.653963, -79.387207.

# %%
display(Markdown("__Plotting the map of Toronto.__"))
# latitude = 79.3832
# longitude = 43.6532
map_torento = folium.Map(location=[latitude, longitude], zoom_start=10)
display(Markdown("__Plotting the map with markers for given coordinates of postal codes in the dataframe.__"))
# add markers to map
for lat, lng, borough, neighborhood in zip(postal_df['Latitude'], postal_df['Longitude'], postal_df['Borough'], postal_df['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_torento)
    
map_torento
# Out:
# __Plotting the map of Toronto.__
# __Plotting the map with markers for given coordinates of postal codes in the dataframe.__
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
